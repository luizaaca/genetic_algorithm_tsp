# %%
from osmnx_utils import initialize_graph, plot_route_segments_info
from route_plot_utils import RouteCalculator as RC
import random

# %%
origin = "Praça da Sé, São Paulo"
destinations = [
    ("Edifício Copan, São Paulo", 1),
    ("Mercado Municipal de São Paulo", 2),
    ((-23.5465, -46.6367), 3),
    ((-23.561543, -46.656197), 2),
    ((-23.544534, -46.665030), 1),
    ((-23.534346, -46.640460), 3),
    ((-23.532278, -46.657468), 2),
    ((-23.531978, -46.634383), 1),
]

# %%
g_proj, route_nodes = initialize_graph(origin, destinations)

# %%
random_nodes = route_nodes[:1] + random.sample(route_nodes[1:], len(route_nodes) - 1)
print(random_nodes)
# Out:
# [('Praça da Sé, São Paulo', 3713156708, (333310.1337213415, 7394600.776624355)), ('MASP Suplicy', 165463204, (330964.49009692564, 7393338.606213607)), ('Rosa E Silva C/B', 457051436, (330797.2801502978, 7396577.888218259)), ('Praça Charles Miller', 1952697074, (330040.92008573643, 7395211.725715005)), ('Sala São Paulo', 2368835875, (332536.48872039357, 7396368.841703221)), ('Rua Líbero Badaró, 309', 617798750, (332935.7533407669, 7395027.313490199)), ('Rua Ribeiro de Lima', 5497521741, (333153.9768501705, 7396638.151982317)), ('Edifício Copan, São Paulo', 1477490865, (332136.16837659583, 7395007.720350906)), ('Mercado Municipal de São Paulo', 248111223, (333662.3314608962, 7395563.523808238))]

# %%
route_calculator = RC(g_proj)
weight_function = route_calculator.get_weight_function()

# %%
segments_info = route_calculator.compute_route_segments_info(random_nodes, weight_function, "priority")

# %%
plot_route_segments_info(g_proj, segments_info)
